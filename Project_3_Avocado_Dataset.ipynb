# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Avocado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# ...

# %%
#Checking the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.shape
# Out:
# (16468, 14)

# %%
#Check the data types of columns
df.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
#Check the information of Data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 1.8+ MB

# %%
Observation:
    There are total 16468 rows and  14 columns
    There are 1517 not null rows out of 16468 rows.
    All columns are in float64 datatype except Date,type and year
    Date,type and year is are in object data type
# Out:
#   File "<ipython-input-13-7a4b4bb505c3>", line 1
#     Observation:
#                 ^
# SyntaxError: invalid syntax

# %%
#Dropping the rows containing null values
df.dropna(inplace=True)

# %%
Obseravtion:
    After dropping the rows there are 1517 rows and 14 columns

# %% [markdown]
# # Summary Statiscs

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
Observation:
    Standard deviation is minimum in Average Price
    Minimum Average price is 0.49 and maximum Average price is 1.68
    In XLarge Bags column difference between 75% and max is more so in these outliers may be present

# %%
#Check the uniwue Average Price
df["AveragePrice"].unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.18, 1.29, 1.25, 1.03, 1.39,
#        1.4 , 1.36, 1.3 , 0.88, 1.21, 0.9 , 0.94, 0.75, 0.77, 0.81, 0.8 ,
#        0.72, 0.79, 0.67, 0.82, 0.68, 0.76, 0.91, 1.38, 0.92, 0.78, 0.74,
#        0.62, 0.83, 0.87, 0.73, 0.7 , 0.89, 0.85, 1.44, 1.42, 1.41, 0.49,
#        0.53, 0.66, 0.56, 0.6 , 0.71, 0.65, 0.58, 0.54, 0.52, 0.51, 0.57,
#        0.63, 0.64, 0.61, 0.84, 0.86, 0.69, 1.52, 1.53, 1.49, 1.48, 1.56,
#        1.62, 1.63, 1.46, 1.51, 1.61, 1.47, 1.66, 1.57, 1.6 , 1.5 , 1.68,
#        1.54, 1.64, 1.58])

# %%
#Check the value counts for AveragePrice
df["AveragePrice"].value_counts()
# Out:
# 1.08    46
# 0.99    44
# 1.03    44
# 1.09    43
# 1.10    43
#         ..
# 1.61     1
# 1.66     1
# 1.60     1
# 0.64     1
# 1.64     1
# Name: AveragePrice, Length: 113, dtype: int64

# %%
Observation:
    Most frequent AveragePrice is 1.08
    0.99 & 1.03 have frequency of 44
    1.09 & 1.10 have frequency of 43

# %% [markdown]
# # Checking fo Missing Values

# %%
#Checking for Null values
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
Observation:
    There is no null value in the dataset. We can see this with visualization for better clarity

# %%
#See the null values with the help of Heatmap
sns.heatmap(df.isnull())

# %%
Obseravation:
    From this visualization we can see that there is no missing values in the dataset.

# %% [markdown]
# # Check the Correlation

# %%
df_cor=df.corr()

# %%
df_cor
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.075531      0.091934  0.092013  0.093566
# AveragePrice   -0.075531      1.000000     -0.140470 -0.190096 -0.092084
# Total Volume    0.091934     -0.140470      1.000000  0.985568  0.987154
# 4046            0.092013     -0.190096      0.985568  1.000000  0.951952
# 4225            0.093566     -0.092084      0.987154  0.951952  1.000000
# 4770            0.075647     -0.100567      0.934347  0.898570  0.927757
# Total Bags      0.081007     -0.111597      0.967689  0.930395  0.951779
# Small Bags      0.083485     -0.097682      0.960642  0.922278  0.943988
# Large Bags      0.065364     -0.177480      0.910226  0.884229  0.900496
# XLarge Bags    -0.050993     -0.048284      0.521717  0.474063  0.504718
# year           -0.012854      0.178683     -0.004189 -0.040439 -0.007254
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
#For better understanding we can see it with the help of Visualization(Heatmap)

plt.figure(figsize=(16,10))
sns.heatmap(df_cor, annot=True , cmap="winter")

# %%
Obseravtion:
    Large bags,Total Bags and  Total Volume is negatively correlated with AveragePrice
    XLarge Bags,Small Bags are less negatively correlated with AveragePrice

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=(16,10))
df["AveragePrice"].plot.bar()
plt.ylabel("AveragePrice")
plt.xlabel("No of Rows")
plt.xticks(rotation=30)
plt.title("AveragePrice per Row")
plt.show()

# %%
plt.figure(figsize=(16,10))
df["Large Bags"].plot.bar()
plt.ylabel("No of Large Bags")
plt.xlabel("No of Rows")
plt.xticks(rotation=30)
plt.title("Total Bags per Row")
plt.show()

# %%
df["Large Bags"].value_counts()
# Out:
# 0.00       134
# 48.89        3
# 8.89         3
# 31.11        2
# 51.11        2
#           ...
# 562.37       1
# 1837.60      1
# 1994.62      1
# 319.56       1
# 93.25        1
# Name: Large Bags, Length: 1377, dtype: int64

# %%
plt.figure(figsize=(16,7))
df["Total Bags"].plot.bar()
plt.ylabel("No of Total Bags")
plt.xlabel("No of Rows")
plt.xticks(rotation=30)
plt.title("Total Bags per Row")
plt.show()

# %%
plt.figure(figsize=(16,7))
df["Total Volume"].plot.bar()
plt.ylabel("No of Total Volume")
plt.xlabel("No of Rows")
plt.xticks(rotation=30)
plt.title("Total Volume per Row")
plt.show()

# %%
df["Total Volume"].plot.hist(bins=10)
plt.title("Histogram of Total Volume")
plt.show()

# %%
sns.set(style="whitegrid")
sns.violinplot(df["AveragePrice"])

# %%
Obseravtion:
    Maximum Average Price is between 0.80 to 1.2
# Out:
#   File "<ipython-input-30-608373ea07fc>", line 1
#     Obseravtion:
#                 ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(40,15))
sns.countplot(df["AveragePrice"])

# %% [markdown]
# # Bivariate Analysis

# %%
sns.set(style="white")
plt.scatter(df["Large Bags"],df["AveragePrice"])
plt.xlabel("Large Bags")
plt.ylabel("AveragePrice")
plt.title("Scatter plot of no of Large Bags vs AveragePrice ")
plt.show()

# %%
sns.set(style="white")
plt.scatter(df["Total Bags"],df["AveragePrice"])
plt.xlabel("Total Bags")
plt.ylabel("AveragePrice")
plt.title("Scatter plot of no of Total Bags vs AveragePrice ")
plt.show()

# %%
sns.set(style="white")
plt.scatter(df["Total Volume"],df["AveragePrice"])
plt.xlabel("Total Volume")
plt.ylabel("AveragePrice")
plt.title("Scatter plot of no of Total Volume vs AveragePrice ")
plt.show()

# %%
sns.set(style="white")
plt.scatter(df["Small Bags"],df["AveragePrice"])
plt.xlabel("Small Bags")
plt.ylabel("AveragePrice")
plt.title("Scatter plot of no of Small Bags vs AveragePrice ")
plt.show()

# %% [markdown]
# # Plotting Outliers

# %%
df["XLarge Bags"].plot.box()

# %%
df["AveragePrice"].plot.box()

# %%
df["Total Volume"].plot.box()

# %%
df["Large Bags"].plot.box()

# %%
df["Small Bags"].plot.box()

# %%
df.shape
# Out:
# (1517, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.drop(columns=["Date","type","region"], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0         0.0          1.33      64236.62  1036.74   54454.85   48.16
# 1         1.0          1.35      54876.98   674.28   44638.81   58.33
# 2         2.0          0.93     118220.22   794.70  109149.67  130.50
# 3         3.0          1.08      78992.15  1132.00   71976.41   72.58
# 4         4.0          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags    year
# 0     8696.87     8603.62       93.25          0.0  2015.0
# 1     9505.56     9408.07       97.49          0.0  2015.0
# 2     8145.35     8042.21      103.14          0.0  2015.0
# 3     5811.16     5677.40      133.76          0.0  2015.0
# 4     6183.95     5986.26      197.69          0.0  2015.0

# %%
collist=df.columns.values
ncol=11
nrow=10

# %%
plt.figure(figsize=(10,40))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color="green",orient="v")
    plt.show()

# %% [markdown]
# # To check the distribution of Skewness

# %%
plt.figure(figsize=(30,20))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(df[collist[i]],color="green")
    plt.tight_layout()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
#Checking skewness of data
df.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %%
#Treating skewness via log method

for col in df.columns:
    if df[col].skew()>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# year            1.828332
# dtype: float64

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.81868039, 1.35048079, 1.35676174, ..., 0.96674301, 0.81077519,
#         0.44100815],
#        [1.75131034, 1.45639674, 1.46638736, ..., 0.95386092, 0.81077519,
#         0.44100815],
#        [1.6839403 , 0.76783831, 0.9321394 , ..., 0.93753117, 0.81077519,
#         0.44100815],
#        ...,
#        [1.01023983, 2.14485045, 0.64565294, ..., 0.34275114, 1.10389091,
#         2.26753179],
#        [0.94286978, 2.09189247, 0.60503087, ..., 0.34346272, 0.81077519,
#         2.26753179],
#        [0.87549974, 1.88006056, 0.62805557, ..., 0.44343485, 0.81077519,
#         2.26753179]])

# %%
threshold=3
np.where(z>3)
# Out:
# (array([ 760, 1182, 1182, 1182, 1183, 1183, 1183, 1184, 1184, 1184, 1185,
#         1185, 1185, 1186, 1186, 1186, 1187, 1188, 1188, 1188, 1189, 1189,
#         1191, 1202, 1346, 1411, 1457, 1458], dtype=int64),
#  array([1, 2, 6, 7, 2, 6, 7, 2, 6, 7, 2, 6, 7, 2, 6, 7, 7, 2, 6, 7, 2, 6,
#         6, 2, 5, 1, 1, 1], dtype=int64))

# %%
z[760][1]
# Out:
# 3.097989311954043

# %%
z[1458][1]
# Out:
# 3.2040099957308414

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (1502, 11)

# %%
df.shape
# Out:
# (1517, 11)

# %%
df=df_new

# %%
df.shape
# Out:
# (1502, 11)

# %%
EDA process is done

# %% [markdown]
# # Model Training

# %%
#Separating into input and output variables

df_x=df.drop(columns=["AveragePrice"])

# %%
y=pd.DataFrame(df["AveragePrice"])

# %%
y.head()
# Out:
#    AveragePrice
# 0          1.33
# 1          1.35
# 2          0.93
# 3          1.08
# 4          1.28

# %%
#Scaling the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#Lets check the skewness

x.skew()
# Out:
# Unnamed: 0     -0.232231
# Total Volume    0.592040
# 4046           -0.203940
# 4225            0.122951
# 4770           -0.371693
# Total Bags      0.621617
# Small Bags      0.643635
# Large Bags     -0.934829
# XLarge Bags     0.796336
# year            1.838704
# dtype: float64

# %%
#Breaking input and output variable into train and test data

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
x_train.shape
# Out:
# (1201, 10)

# %%
x_test.shape
# Out:
# (301, 10)

# %%
y_train.shape
# Out:
# (1201, 1)

# %%
y_test.shape
# Out:
# (301, 1)

# %%
#Importing Models Library


from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Importing Error Metrices

from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
#Using algorithms via for loop

model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    m.fit(x_train,y_train)
    print("score of ",m ,"is:",m.score(x_train,y_train))
    predm=m.predict(x_test)
    print("Error:")
    print("Mean absolute error:",mean_absolute_error(y_test,predm))
    print("Mean squared error:"),mean_squared_error(y_test,predm)
    print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predm)))
    print("r2_score:",r2_score(y_test,predm))
    print("******************************************************")
    print("\n")
# Out:
# score of  LinearRegression() is: 0.37849503005679785
# Error:
# Mean absolute error: 0.11183436180858405
# Mean squared error:
# Root Mean Squared Error: 0.13888574179937294
# r2_score: 0.42812672864195456
# ******************************************************
#
#
# score of  DecisionTreeRegressor() is: 1.0
# Error:
# Mean absolute error: 0.07601328903654483
# Mean squared error:
# Root Mean Squared Error: 0.1004541183841271
# r2_score: 0.7008286741410081
# ******************************************************
#
#
# score of  KNeighborsRegressor() is: 0.8660018168596582
# Error:
# Mean absolute error: 0.06303654485049832
# Mean squared error:
# Root Mean Squared Error: 0.08070906695267943
# r2_score: 0.8068791668493694
# ******************************************************
#
#
# score of  SVR() is: 0.8199310821763331
# Error:
# Mean absolute error: 0.06724986496837637
# Mean squared error:
# Root Mean Squared Error: 0.08484396720843207
# r2_score: 0.7865842790097581
# ...

# %%
#@DecisionTreeRegressor is giving best result so finding its best parameter using GridSearchCV

from sklearn.model_selection import GridSearchCV
DTR=DecisionTreeRegressor()
parameters={"alpha":[0.001,0.01,0.1,1],"random_state":range(42,100)}
clf=GridSearchCV(DTR,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-4f5fe98b7812> in <module>
#       5 parameters={"alpha":[0.001,0.01,0.1,1],"random_state":range(42,100)}
#       6 clf=GridSearchCV(DTR,parameters)
# ----> 7 clf.fit(x,y)
#       8 clf.best_params_
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ...
