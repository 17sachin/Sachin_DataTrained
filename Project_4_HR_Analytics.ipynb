# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("HR_attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
#Checking the columns
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#Checking data types of columns

df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#Checking information of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
Observation:
    There are 1470 rows and 35 columns
    No missing value present in dataset
    Out of 35, 9 columns are of object data type
    26 columns are in int64 data type
# Out:
#   File "<ipython-input-40-0c02491776c0>", line 1
#     Observation:
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Summary Statiscs

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
Obseravation:
    Standard deviation for EmployeeNumber is maximum
    In DailyRate,EmployeeNumber,DistanceFromHome columns the 75% and max is more so in these columns outliers may be present
    The Minimum age is 18 and Maximum age is 60
    The maximum employee number is 2068

# %%
#Check the unique attrition
df["Attrition"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#Check the value counts for Attrition

df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
Observation:
    "No" has maximum frequency of 1233
    "Yes" has frequency of 237
# Out:
#   File "<ipython-input-44-d8bd30730772>", line 1
#     Observation:
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Checking for Missing Values

# %%
#Checking for Null values

df["Attrition"].isnull().sum()
# Out:
# 0

# %%
Obseravtion:
    No null value in the dataset. We can see this also with the help of visulaization

# %%
#Seeing the null values with the help of heatmap

plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())

# %%
Obseravation:
    From this visualization we can conclude that there is no missing values in the dataset

# %% [markdown]
# # To check the Correlation

# %%
df_cor=df.corr()
df_cor
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
For better understanding we will try to visualize it through heatmap

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df_cor,annot=True,cmap="winter")

# %%
Obseravation:
    JobLevel,MonthlyIncome and TotalWorkingYears are poorly correlated .
    Yearsatcompany,YearsinCurrentRole,Yearsincelastpromotion and YearwithCurrManager are strongly correlated

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

list1=["Attrition","BusinessTravel","Department","EducationField","Gender","JobRole","MaritalStatus","Over18","OverTime"]
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
df.dtypes
# Out:
# Age                           int64
# Attrition                   float64
# BusinessTravel                int32
# DailyRate                     int64
# Department                    int32
# DistanceFromHome            float64
# Education                     int64
# EducationField              float64
# EmployeeCount                 int64
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# Gender                        int32
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                    float64
# JobRole                       int32
# JobSatisfaction               int64
# MaritalStatus                 int32
# MonthlyIncome               float64
# MonthlyRate                   int64
# NumCompaniesWorked          float64
# Over18                        int32
# OverTime                    float64
# PercentSalaryHike           float64
# PerformanceRating           float64
# RelationshipSatisfaction      int64
# ...

# %% [markdown]
# # Plotting Outliers

# %%
df["DailyRate"].plot.box()

# %%
df["EmployeeNumber"].plot.box()

# %%
df["DistanceFromHome"].plot.box()

# %%
df.shape
# Out:
# (1470, 35)

# %%
collist=df.columns.values
ncol=35
nrow=10

# %%
plt.figure(figsize=(35,30))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color="green",orient="v")
    plt.tight_layout()

# %% [markdown]
# # To Check the distribution of Skewness

# %%
plt.figure(figsize=(30,20))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(df[collist[i]],color="green")
    plt.tight_layout()

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %%
#Check skewness of data

df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# ...

# %%
#Treating skewness via LogMethod

for col in df.columns:
    if df[col].skew()>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.029121
# Education                  -0.289681
# EducationField             -0.054786
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.448133
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.286448
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.092896
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.513543
# PerformanceRating           1.921883
# ...

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.4463504 , 2.28090588, 0.59004834, ..., 0.29061127, 0.97334237,
#         0.54799589],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.88267046, 0.11727147,
#         0.90492352],
#        [0.008343  , 2.28090588, 0.59004834, ..., 1.73678265, 0.97334237,
#         1.67504313],
#        ...,
#        [1.08667552, 0.4384223 , 0.59004834, ..., 0.352871  , 0.97334237,
#         0.04493464],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.71446221, 0.97334237,
#         1.05105714],
#        [0.32016256, 0.4384223 , 0.59004834, ..., 0.00951942, 0.11727147,
#         0.311993  ]])

# %%
threshold=3
np.where(z>3)
# Out:
# (array([   0,   23,   43,   45,   69,   94,  127,  135,  180,  201,  258,
#          261,  286,  293,  296,  301,  322,  331,  370,  401,  457,  487,
#          512,  559,  596,  615,  649,  658,  709,  719,  722,  727,  735,
#          770,  797,  798,  817,  828,  828,  833,  942,  957,  958,  966,
#          972,  973,  976,  978,  981,  984, 1039, 1044, 1125, 1133, 1153,
#         1169, 1170, 1246, 1301, 1311, 1360, 1369, 1376, 1401, 1467],
#        dtype=int64),
#  array([29, 28, 29, 29, 29, 29, 28, 29, 29, 29, 29, 29, 29, 29, 28, 28, 29,
#         29, 29, 29, 28, 29, 29, 29, 29, 28, 29, 29, 29, 29, 29, 28, 29, 29,
#         29, 29, 29, 28, 29, 29, 29, 29, 29, 29, 28, 29, 29, 29, 29, 29, 29,
#         29, 29, 29, 28, 29, 29, 29, 29, 28, 29, 29, 29, 29, 29],
#        dtype=int64))

# %%
z[23][28]
# Out:
# 3.285032383741204

# %%
z[1467][29]
# Out:
# 3.3654352688451055

# %%
#IQR=Q3-Q1

# %%
Q1=df.quantile(0.25)

# %%
Q3=df.quantile(0.75)

# %%
Q1
# Out:
# Age                           30.000000
# Attrition                      0.000000
# BusinessTravel                 1.000000
# DailyRate                    465.000000
# Department                     1.000000
# DistanceFromHome               1.098612
# Education                      2.000000
# EducationField                 0.693147
# EmployeeCount                  1.000000
# EmployeeNumber               491.250000
# EnvironmentSatisfaction        2.000000
# Gender                         0.000000
# HourlyRate                    48.000000
# JobInvolvement                 2.000000
# JobLevel                       0.693147
# JobRole                        2.000000
# JobSatisfaction                2.000000
# MaritalStatus                  1.000000
# MonthlyIncome                  7.976595
# MonthlyRate                 8047.000000
# NumCompaniesWorked             0.693147
# Over18                         0.000000
# OverTime                       0.000000
# ...

# %%
Q3
# Out:
# Age                            43.000000
# Attrition                       0.000000
# BusinessTravel                  2.000000
# DailyRate                    1157.000000
# Department                      2.000000
# DistanceFromHome                2.708050
# Education                       4.000000
# EducationField                  1.386294
# EmployeeCount                   1.000000
# EmployeeNumber               1555.750000
# EnvironmentSatisfaction         4.000000
# Gender                          1.000000
# HourlyRate                     83.750000
# JobInvolvement                  3.000000
# JobLevel                        1.386294
# JobRole                         7.000000
# JobSatisfaction                 4.000000
# MaritalStatus                   2.000000
# MonthlyIncome                   9.033603
# MonthlyRate                 20461.500000
# NumCompaniesWorked              1.609438
# Over18                          0.000000
# OverTime                        0.693147
# ...

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# Age                            13.000000
# Attrition                       0.000000
# BusinessTravel                  1.000000
# DailyRate                     692.000000
# Department                      1.000000
# DistanceFromHome                1.609438
# Education                       2.000000
# EducationField                  0.693147
# EmployeeCount                   0.000000
# EmployeeNumber               1064.500000
# EnvironmentSatisfaction         2.000000
# Gender                          1.000000
# HourlyRate                     35.750000
# JobInvolvement                  1.000000
# JobLevel                        0.693147
# JobRole                         5.000000
# JobSatisfaction                 2.000000
# MaritalStatus                   1.000000
# MonthlyIncome                   1.057008
# MonthlyRate                 12414.500000
# NumCompaniesWorked              0.916291
# Over18                          0.000000
# OverTime                        0.693147
# ...

# %%
(df<(Q1-(1.5 * IQR )))| (df>(Q3 + (1.5 * IQR)))
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False       True           False      False       False
# 1     False      False           False      False       False
# 2     False       True           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %% [markdown]
# df_n1

# %%
y=df["Attrition"]

# %%
y.head()
# Out:
# 0    0.693147
# 1    0.000000
# 2    0.693147
# 3    0.000000
# 4    0.000000
# Name: Attrition, dtype: float64
